# %% [markdown]
# <a href="https://colab.research.google.com/github/sendmail123/DataScience/blob/master/ImageColoring.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# !wget "/Users/vishalsingh/Desktop/Data/ML/ComputerVision/Computer-Vision-with-Python/DATA"
# Out:
# /Users/vishalsingh/Desktop/Data/ML/ComputerVision/Computer-Vision-with-Python/DATA: Scheme missing.

# %%
# !ls
# Out:
# '00-puppy (1).jpg'   00-puppy.jpg   dog_backpack.jpg   sample_data

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9ab58226-2814-47a4-b3af-a0f9a80ba252" name="files[]" multiple disabled />
#      <output id="result-9ab58226-2814-47a4-b3af-a0f9a80ba252">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
img = cv2.imread("dog_backpack.jpg")
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
fl = cv2.flip(fix_img,-1)
plt.imshow(fl)

# %%
plt.imshow(cv2.rectangle(fix_img,pt1=(220,400),pt2=(550,750),color=(255,0,0), thickness=10))

# %%
vertices = np.array([[300,400],[200,700],[600,700]],dtype = np.int32)

# %%
vertices.shape
# Out:
# (3, 2)

# %%
pts=vertices.reshape((-1,1,2))

# %%
pts.shape
# Out:
# (3, 1, 2)

# %%
cv2.polylines(fix_img,[pts], isClosed=True,color= (255,0,0), thickness = 10)
plt.imshow(fix_img)

# %%
cv2.fillPoly(fix_img,[pts], color= (255,0,0))
plt.imshow(fix_img)

# %%
plt.imshow(img)

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_RGB2HLS)
plt.imshow(fix_img)

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_RGB2HLS)
plt.imshow(fix_img)
