# %% [markdown]
# <a href="https://colab.research.google.com/github/sendmail123/DataScience/blob/master/OpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-da9cf5dc-c66a-4475-b797-331b229beb03" name="files[]" multiple disabled />
#      <output id="result-da9cf5dc-c66a-4475-b797-331b229beb03">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 00-puppy.jpg to 00-puppy.jpg

# %%
# !wget "/Users/vishalsingh/Desktop/Data/ML/ComputerVision/Computer-Vision-with-Python/DATA"
# Out:
# /Users/vishalsingh/Desktop/Data/ML/ComputerVision/Computer-Vision-with-Python/DATA: Scheme missing.

# %%
# !ls
# Out:
# 00-puppy.jpg  sample_data

# %%
img = cv2.imread("00-puppy.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(img)

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread("00-puppy.jpg", cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
img_gray.shape
# Out:
# (1300, 1950)

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (1300, 1950, 3)

# %%
new_img=cv2.resize(fix_img,(1000,400))
new_img.shape
# Out:
# (400, 1000, 3)

# %%
plt.imshow(new_img)

# %%
new_img = cv2.resize(fix_img,(0,0),fix_img,0.5,0.5)
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (650, 975, 3)

# %%
new_img = cv2.flip(fix_img,-1)
plt.imshow(new_img)

# %%
cv2.imwrite("totaly_new.jpg",new_img)
# Out:
# True

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
ax.imshow(fix_img)

# %%
#

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(fix_img)
# Out:
# <PIL.Image.Image image mode=RGB size=1950x1300 at 0x7F1D13FC6A58>
